# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
iris_data = sns.load_dataset('iris')

# %%
iris_data

sns.barplot(iris_data, x = 'species', y = 'petal_length', hue='species')
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
sns.histplot(iris_data, x = 'species', y = 'petal_length', hue='species', palette='rocket')
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_data.describe()
iris_data.groupby('species').mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
pd.value_counts(iris_data['species'])
# Out:
# C:\Users\pk826\AppData\Local\Temp\ipykernel_11876\3560406982.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(iris_data['species'])
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
sns.histplot(iris_data,x='sepal_length',hue = 'species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.kdeplot(iris_data,x='sepal_length',hue = 'species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
sns.kdeplot(iris_data,x='sepal_width',hue = 'species')
# Out:
# <Axes: xlabel='sepal_width', ylabel='Density'>

# %%
# sns.kdeplot(iris_data,x='petal_length',hue = 'species',cumulative=True)
sns.kdeplot(iris_data,x='petal_length',hue = 'species')
# Out:
# <Axes: xlabel='petal_length', ylabel='Density'>

# %%
sns.kdeplot(iris_data,x='petal_width',hue = 'species')
# Out:
# <Axes: xlabel='petal_width', ylabel='Density'>

# %%
sns.jointplot(iris_data,x = 'sepal_length',y='sepal_width',hue = 'species')

# %%
sns.jointplot(iris_data,x = 'petal_length',y='petal_width',hue = 'species',kind='kde')

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import load_iris
import pandas as pd

# Create the 3D plot
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Plot data points for each species
for species_name in np.unique(iris_data['species']):
    subset = iris_data[iris_data['species'] == species_name]
    ax.scatter(
        subset['petal_length'],
        subset['petal_width'],
        subset['sepal_length'],
        label=species_name
    )

# Label the axes
ax.set_xlabel('petal_length')
ax.set_ylabel('petal_width')
ax.set_zlabel('sepal_length')

# Add a legend
ax.legend(title="Species")

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 3
#       1 import matplotlib.pyplot as plt
#       2 from mpl_toolkits.mplot3d import Axes3D
# ----> 3 from sklearn.datasets import load_iris
#       4 import pandas as pd
#       6 # Create the 3D plot
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
sns.pairplot(iris_data,hue = 'species')

# %%
iris_data.corr(numeric_only = True)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris_data.corr(numeric_only = True),annot=True)
# Out:
# <Axes: >

# %%
count,values = np.histogram(iris_data[iris_data['species'] == 'setosa']['petal_length'],7)

# %%
count = np.cumsum(count)/np.sum(count)

# %%
count
# Out:
# array([0.04, 0.08, 0.22, 0.74, 0.88, 0.96, 1.  ])

# %%
plt.plot(count,values[:-1])
plt.show()
